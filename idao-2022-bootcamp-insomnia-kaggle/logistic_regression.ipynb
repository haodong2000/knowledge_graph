# %%
import pandas as pd
import seaborn
import numpy as np

# %%
import param

# %%
train_data = pd.read_csv(param.Train_datapath)
test_data = pd.read_csv(param.Test_datapath)

# %%
seaborn.pairplot(train_data)

# %%
train_data.head()
# Out:
#    id        age  weight  height  sex  stress  doctor  sport  pernicious_1  \
# 0   0  50.357290    62.0     168    2       1       1      1             0
# 1   1  55.381246    85.0     156    1       3       1      1             0
# 2   2  51.627652    64.0     165    1       3       1      0             0
# 3   3  48.249144    82.0     169    2       1       1      1             0
# 4   4  47.841205    56.0     156    1       1       1      0             0
#
#    pernicious_2  ubp  lbp  insomnia
# 0             0  110   80         0
# 1             0  140   90         1
# 2             0  130   70         1
# 3             0  150  100         1
# 4             0  100   60         0

# %%
import sklearn.preprocessing

train_data_val = train_data.values
scaler = sklearn.preprocessing.StandardScaler(with_mean=True, with_std=True)
